# %%
# flip horizontal, flip vertical, or both 
# rotate 90,180 or 270

# %%
import cv2
import numpy as np
import re
from tqdm import tqdm
import os
import random
from PIL import Image, ImageEnhance

# %%
def augment(image):    
    def transform():
        return random.choice([0,1,2])

    # every image has to flip    
    transform_seed = transform()         
    if transform_seed == 0:
        image = cv2.flip(image, 0) #horizontal 
    elif transform_seed == 1:
        image = cv2.flip(image, 1) #vert
    else:
        image = cv2.flip(image, -1) #both

    # every image also has to rotate
    transform_seed2 = transform()
    if transform_seed2 == 0:
        image = cv2.rotate(image, cv2.cv2.ROTATE_90_CLOCKWISE) 
    elif transform_seed2 == 1:
        image = cv2.rotate(image, cv2.ROTATE_180)
    else:
        image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)

    return image

# %%
# read img
def fast_scandir(dirname):
    subfolders= [f.path for f in os.scandir(dirname) if f.is_dir()]
    for dirname in list(subfolders):
        subfolders.extend(fast_scandir(dirname))
    return subfolders

read_dir = fast_scandir('/media/zheng/backup/shipclassification/dataset/split_aug/split/train/')
read_dir
#/media/zheng/backup/shipclassification/dataset/split_aug/aug/train/
# Out:
# ['/media/zheng/backup/shipclassification/dataset/split_aug/split/train/oil_tank',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/train/submarine',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/train/cruiser',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/train/boat',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/train/bulk_cargo',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/train/yacht',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/train/container']

# %%
expand_times = 4

for dire in read_dir:    
    for filename in os.listdir(dire):                    
        path = dire + '/' + filename
        image = cv2.imread(path)
        filename = filename[:-4]
        
        for i in range(expand_times): 
            img_aug = augment(image)
            #save aug img, string problem
            filename = filename + '_' + str(i) + '.png'
            save_dir = dire[0:56] + '/aug' + dire[62:]
            print(save_dir)
            cv2.imwrite(os.path.join(save_dir, filename), img_aug)
            filename = filename[:-6]
# Out:
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/train/oil_tank
# ...

# %%
len("/media/zheng/backup/shipclassification/dataset/split_aug/")
# Out:
# 57

# %%
len("/media/zheng/backup/shipclassification/dataset/split_aug/split")
# Out:
# 62

# %%
# read test img
def fast_scandir(dirname):
    subfolders= [f.path for f in os.scandir(dirname) if f.is_dir()]
    for dirname in list(subfolders):
        subfolders.extend(fast_scandir(dirname))
    return subfolders

read_dir = fast_scandir('/media/zheng/backup/shipclassification/dataset/split_aug/split/test/')
read_dir
#/media/zheng/backup/shipclassification/dataset/split_aug/aug/test/
# Out:
# ['/media/zheng/backup/shipclassification/dataset/split_aug/split/test/oil_tank',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/test/submarine',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/test/cruiser',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/test/boat',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/test/bulk_cargo',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/test/yacht',
#  '/media/zheng/backup/shipclassification/dataset/split_aug/split/test/container']

# %%
expand_times = 4

for dire in read_dir:    
    for filename in os.listdir(dire):                    
        path = dire + '/' + filename
        image = cv2.imread(path)
        filename = filename[:-4]
        
        for i in range(expand_times): 
            img_aug = augment(image)
            #save aug img, string problem
            filename = filename + '_' + str(i) + '.png'
            save_dir = dire[0:56] + '/aug' + dire[62:]
            print(save_dir)
            cv2.imwrite(os.path.join(save_dir, filename), img_aug)
            filename = filename[:-6]
# Out:
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug/test/oil_tank
# ...

# %%
# balanced data
import cv2
import numpy as np
import re
from tqdm import tqdm
import os
import random
from PIL import Image, ImageEnhance

def augment(image):    
    def transform():
        return random.choice([0,1,2])

    # every image has to flip    
    transform_seed = transform()         
    if transform_seed == 0:
        image = cv2.flip(image, 0) #horizontal 
    elif transform_seed == 1:
        image = cv2.flip(image, 1) #vert
    else:
        image = cv2.flip(image, -1) #both

    # every image also has to rotate
    transform_seed2 = transform()
    if transform_seed2 == 0:
        image = cv2.rotate(image, cv2.cv2.ROTATE_90_CLOCKWISE) 
    elif transform_seed2 == 1:
        image = cv2.rotate(image, cv2.ROTATE_180)
    else:
        image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)

    return image

# read img
def fast_scandir(dirname):
    subfolders= [f.path for f in os.scandir(dirname) if f.is_dir()]
    for dirname in list(subfolders):
        subfolders.extend(fast_scandir(dirname))
    return subfolders

read_dir = fast_scandir('/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train2')
#read_dir = fast_scandir('/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test2')
#read_dir = ['/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train2','/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test2']

expand_times = 4

for dire in read_dir:    
    for filename in os.listdir(dire):                    
        path = dire + '/' + filename
        image = cv2.imread(path)
        filename = filename[:-4]
        
        for i in range(expand_times): 
            img_aug = augment(image)
            #save aug img, string problem
            filename = filename + '_' + str(i) + '.png'
            save_dir = dire[0:74] + '/train3' + dire[81:]
            print(save_dir)
            cv2.imwrite(os.path.join(save_dir, filename), img_aug)
            filename = filename[:-6]
# Out:
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train3/oil_tank
# ...

# %%
len('/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass')
# Out:
# 74

# %%
len('/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train2')
# Out:
# 81

# %%
# balanced data
import cv2
import numpy as np
import re
from tqdm import tqdm
import os
import random
from PIL import Image, ImageEnhance

def augment(image):    
    def transform():
        return random.choice([0,1,2])

    # every image has to flip    
    transform_seed = transform()         
    if transform_seed == 0:
        image = cv2.flip(image, 0) #horizontal 
    elif transform_seed == 1:
        image = cv2.flip(image, 1) #vert
    else:
        image = cv2.flip(image, -1) #both

    # every image also has to rotate
    transform_seed2 = transform()
    if transform_seed2 == 0:
        image = cv2.rotate(image, cv2.cv2.ROTATE_90_CLOCKWISE) 
    elif transform_seed2 == 1:
        image = cv2.rotate(image, cv2.ROTATE_180)
    else:
        image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)

    return image

# read img
def fast_scandir(dirname):
    subfolders= [f.path for f in os.scandir(dirname) if f.is_dir()]
    for dirname in list(subfolders):
        subfolders.extend(fast_scandir(dirname))
    return subfolders

#read_dir = fast_scandir('/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train2')
read_dir = fast_scandir('/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test2')
#read_dir = ['/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/train2','/media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test2']

expand_times = 4

for dire in read_dir:    
    for filename in os.listdir(dire):                    
        path = dire + '/' + filename
        image = cv2.imread(path)
        filename = filename[:-4]
        
        for i in range(expand_times): 
            img_aug = augment(image)
            #save aug img, string problem
            filename = filename + '_' + str(i) + '.png'
            save_dir = dire[0:74] + '/test3' + dire[80:]
            print(save_dir)
            cv2.imwrite(os.path.join(save_dir, filename), img_aug)
            filename = filename[:-6]
# Out:
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# /media/zheng/backup/shipclassification/dataset/split_aug/aug_balancedclass/test3/oil_tank
# ...
